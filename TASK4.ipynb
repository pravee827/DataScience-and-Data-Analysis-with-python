# %% [markdown]
# <a href="https://colab.research.google.com/github/pravee827/DataScience-and-Data-Analysis-with-python/blob/main/TASK4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("Titanic-Dataset.csv")

# Data Cleaning
df["Age"] = df["Age"].fillna(df["Age"].median())
df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])

if "Cabin" in df.columns:
    df.drop("Cabin", axis=1, inplace=True)

    df.drop_duplicates(inplace=True)

    # Feature Engineering
    df["FamilySize"] = df["SibSp"] + df["Parch"] + 1

    # Visualization 1
    plt.figure(figsize=(6,4))
    sns.countplot(x="Survived", data=df)
    plt.title("Survival Count")
    plt.show()

    # Visualization 2
    plt.figure(figsize=(6,4))
    sns.barplot(x="Sex", y="Survived", data=df)
    plt.title("Survival Rate by Gender")
    plt.show()

    # Visualization 3
    plt.figure(figsize=(6,4))
    sns.barplot(x="Pclass", y="Survived", data=df)
    plt.title("Survival Rate by Passenger Class")
    plt.show()

    # Visualization 4
    plt.figure(figsize=(8,4))
    sns.histplot(df["Age"], bins=30, kde=True)
    plt.title("Age Distribution")
    plt.show()

    # Visualization 5
    plt.figure(figsize=(8,4))
    sns.histplot(df["Fare"], bins=30, kde=True)
    plt.title("Fare Distribution")
    plt.show()

    # Visualization 6
    plt.figure(figsize=(6,4))
    sns.boxplot(x="Survived", y="Age", data=df)
    plt.title("Age vs Survival")
    plt.show()

    # Visualization 7
    plt.figure(figsize=(8,4))
    sns.barplot(x="FamilySize", y="Survived", data=df)
    plt.title("Family Size vs Survival")
    plt.show()

    # Visualization 8
    plt.figure(figsize=(6,4))
    sns.barplot(x="Embarked", y="Survived", data=df)
    plt.title("Embarked vs Survival")
    plt.show()

    # Correlation Heatmap
    plt.figure(figsize=(10,6))
    numeric_df = df.select_dtypes(include=np.number)
    sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
    plt.title("Correlation Heatmap")
    plt.show()

    print("Task 4 Completed Successfully")
# Out:
# Task 4 Completed Successfully
